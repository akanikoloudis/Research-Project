# %% [markdown]
# # Library Imports

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, StorageContext
from llama_index.core.node_parser import SentenceWindowNodeParser
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.embeddings.mistralai import MistralAIEmbedding
from llama_index.llms.openai import OpenAI
from llama_index.core.schema import TextNode
from llama_index.core.settings import Settings
from llama_index.core.schema import Document
from llama_index.core.chat_engine.types import ChatMessage
from llama_index.core.base.llms.types import MessageRole
from collections import defaultdict
from datetime import datetime
import re
import os
import json
import random
from dotenv import load_dotenv
import chromadb
import time
from rank_bm25 import BM25Okapi
import numpy as np

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:997)>

# %% [markdown]
# ## Setup: Load the Environment, Initialize LLM, Embedding, and Vector Store
#
# We sets up the environment and core components for the RAG pipeline. It loads environment variables (such as the Mistral API key), initializes the GPT-4o-mini model from OpenAI for downstream tasks, and configures a persistent ChromaDB vector store to manage document embeddings. The embedding model used is from MistralAI, and batch processing parameters like `CHUNK_SIZE`, `BATCH_SIZE`, and `TOP_K` are also defined here as global paraemeters, to control retrieval behavior and performance during document indexing and querying.

# %%
# Load environment variables from .env file
load_dotenv()

# Get API keys from environment variables
mistral_api_key = os.getenv('MISTRAL_API_KEY')
print(f"Mistral API key loaded: {'Yes' if mistral_api_key else 'No'}")
llm = OpenAI(model="gpt-4o-mini", temperature=0.1)
persist_dir = "../index/vector_chunk_size_4"
os.makedirs(persist_dir, exist_ok=True)

# Initialize Chroma client and collection
chroma_client = chromadb.Client()
chroma_collection = chroma_client.create_collection("congressional_docs")
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# Initialize embedding model
embed_model = MistralAIEmbedding(api_key=mistral_api_key)

# Set batch processing parameters
BATCH_SIZE = 10
DELAY = 1  # seconds between batches
index = None
CHUNK_SIZE = 10 # or whatever default you want
TOP_K = 3
# Out:
# Mistral API key loaded: Yes

# %% [markdown]
# ## Load and Clean Data
#
# We load the data, which is in PDF format, using 'SimpleDirectoryReader', which automatically selects the best file reader based on the file extensions.
#
# After loading, we proceed with cleaning the data by removing any sequence of whitespace characters, such as excessive spaces, tabs, or line breaks, and replacing them with a single white space. This step helps ensure consistent formatting before further processing.

# %%
def clean_text(text):
    """Clean text by normalizing whitespace."""
    return re.sub(r'\s+', ' ', text).strip()

def load_and_clean_documents(path):
    """Load and clean PDF documents from the specified path, grouping by file."""
    raw_docs = SimpleDirectoryReader(
        input_dir=path,
        required_exts=[".pdf"],
        filename_as_id=True
    ).load_data()

    # Group texts by file 
    grouped = defaultdict(list)
    for doc in raw_docs:
        file_key = doc.metadata.get('file_name', doc.doc_id)
        grouped[file_key].append(doc.text)

    cleaned_docs = [
        Document(text=clean_text(" ".join(texts)), metadata={"file_name": file_key}, doc_id=file_key)
        for file_key, texts in grouped.items()
    ]
    return cleaned_docs

# Prints use for debugging to show the three documents created
documents = load_and_clean_documents("/Users/alexnikoloudis/Desktop/research project/development/document")
print(f"Loaded and cleaned {len(documents)} documents")
for i, doc in enumerate(documents):
    print(f"\nDocument {i+1}:")
    print(doc.text[:500])
    print("-" * 80)
# Out:
# Ignoring wrong pointing object 126 0 (offset 0)
# Ignoring wrong pointing object 79 0 (offset 0)
# Ignoring wrong pointing object 89 0 (offset 0)
# Loaded and cleaned 3 documents
#
# Document 1:
# PREPARING FOR THE NEXT PANDEMIC: LESSONS LEARNED AND THE PATH FORWARD ======================================================================= HEARING BEFORE THE SELECT SUBCOMMITTEE ON THE CORONAVIRUS PANDEMIC OF THE COMMITTEE ON OVERSIGHT AND ACCOUNTABILITY U.S. HOUSE OF REPRESENTATIVES ONE HUNDRED EIGHTEENTH CONGRESS SECOND SESSION __________ NOVEMBER 14, 2024 __________ Serial No. 118-136 __________ Printed for the use of the Committee on Oversight and Accountability [GRAPHIC(S) NOT AVAILABLE
# --------------------------------------------------------------------------------
#
# Document 2:
# THE BORDER CRISIS: THE COST OF CHAOS ======================================================================= HEARING before the SUBCOMMITTEE ON NATIONAL SECURITY, THE BORDER, AND FOREIGN AFFAIRS of the COMMITTEE ON OVERSIGHT AND ACCOUNTABILITY U.S. HOUSE OF REPRESENTATIVES ONE HUNDRED EIGHTEENTH CONGRESS SECOND SESSION __________ SEPTEMBER 25, 2024 __________ Serial No. 118-134 __________ Printed for the use of the Committee on Oversight and Accountability [GRAPHIC(S) NOT AVAILABLE IN TIFF FORMA
# --------------------------------------------------------------------------------
#
# Document 3:
# [House Hearing, 118 Congress] [From the U.S. Government Publishing Office KITCHEN TABLE ECONOMICS: HOW FAILED BIDEN-HARRIS POLICIES CONTINUE TO HURT CONSUMERS ======================================================================= HEARING BEFORE THE SUBCOMMITTEE ON ECONOMIC GROWTH, ENERGY POLICY, AND REGULATORY AFFAIRS OF THE COMMITTEE ON OVERSIGHT AND ACCOUNTABILITY U.S. HOUSE OF REPRESENTATIVES ONE HUNDRED EIGHTEENTH CONGRESS SECOND SESSION __________ SEPTEMBER 25, 2024 __________ Serial No. 1
# --------------------------------------------------------------------------------

# %% [markdown]
# ##  BM25 Indexing and Chunk Validation
#
# This script processes a collection of cleaned document objects by:
#
# 1. **Chunking** each document into overlapping windows of sentences
#    - Window sizes: 4, 5, or 6 sentences per chunk
#    - Overlap: 1 sentence between chunks
#
# 2. **Tokenizing** each chunk into lowercase words
#
# 3. **Indexing** the tokenized chunks using the **BM25 algorithm**
#    - This supports lexical information retrieval based on keyword matching
#
# The script also prints out:
# - A sample chunk for each window size
# - The number of sentences in each sample
#
# This helps validate the correctness and behavior of the chunking process.

# %%
#custom splitter for the documents, to split the documents into sentences that will be used for the chunking
def split_into_sentences(text):
    """Split text into sentences using punctuation."""
    return re.split(r'(?<=[.!?]) +', text)

def chunk_documents_manual(documents, window_size):
    nodes = []
    for doc in documents:
        sentences = split_into_sentences(doc.text)
        for i in range(0, len(sentences), window_size):
            group = sentences[i : i + window_size]
            if not group:
                continue
            chunk_text = " ".join(group).strip()
            if chunk_text:
                nodes.append(TextNode(text=chunk_text, metadata=doc.metadata))
    return nodes

# Apply for multiple window sizes
for size in [4,5,6, 8]:
    print(f"\n--- Window size = {size} ---")
    nodes = chunk_documents_manual(documents, window_size=size)
    
    # Print the first node and its sentence count
    sample_text = nodes[0].text
    sent_count = len(split_into_sentences(sample_text))
    print("\nSample chunk (first node):")
    print(sample_text)
    print("Sentence count in this node:", sent_count)
# Out:
# --- Window size = 4 ---
#
# Sample chunk (first node):
# PREPARING FOR THE NEXT PANDEMIC: LESSONS LEARNED AND THE PATH FORWARD ======================================================================= HEARING BEFORE THE SELECT SUBCOMMITTEE ON THE CORONAVIRUS PANDEMIC OF THE COMMITTEE ON OVERSIGHT AND ACCOUNTABILITY U.S. HOUSE OF REPRESENTATIVES ONE HUNDRED EIGHTEENTH CONGRESS SECOND SESSION __________ NOVEMBER 14, 2024 __________ Serial No. 118-136 __________ Printed for the use of the Committee on Oversight and Accountability [GRAPHIC(S) NOT AVAILABLE IN TIFF FORMAT] Available on: govinfo.gov, oversight.house.gov or docs.house.gov _______ U.S. GOVERNMENT PUBLISHING OFFICE 57-441 PDF WASHINGTON : 2025 COMMITTEE ON OVERSIGHT AND ACCOUNTABILITY JAMES COMER, Kentucky, Chairman Jim Jordan, Ohio Jamie Raskin, Maryland, Ranking Mike Turner, Ohio Minority Member Paul Gosar, Arizona Eleanor Holmes Norton, District of Virginia Foxx, North Carolina Columbia Glenn Grothman, Wisconsin Stephen F.
# Sentence count in this node: 4
#
# --- Window size = 5 ---
#
# Sample chunk (first node):
# PREPARING FOR THE NEXT PANDEMIC: LESSONS LEARNED AND THE PATH FORWARD ======================================================================= HEARING BEFORE THE SELECT SUBCOMMITTEE ON THE CORONAVIRUS PANDEMIC OF THE COMMITTEE ON OVERSIGHT AND ACCOUNTABILITY U.S. HOUSE OF REPRESENTATIVES ONE HUNDRED EIGHTEENTH CONGRESS SECOND SESSION __________
#
# This part of the pipeline is responsible for gradually adding all preprocessed document chunks into the system that supports question answering. Instead of uploading everything at once, the data is split into smaller groups and added in steps. This helps prevent issues that might occur if too much information is sent at once.
#
# To ensure the system doesn’t break when it gets overwhelmed, it also includes a waiting mechanism. If the system signals that it’s too busy (due to too many requests), the process waits and tries again after a short pause. This retry approach helps make the upload process more stable and reliable, especially when working with large amounts of data.

# %%
max_retries = 5
nodes = chunk_documents_manual(documents, window_size=CHUNK_SIZE)
for i in range(0, len(nodes), BATCH_SIZE):
    batch = nodes[i:i + BATCH_SIZE]
    print(f"Processing batch {i//BATCH_SIZE + 1} of {(len(nodes) + BATCH_SIZE - 1)//BATCH_SIZE}")

    if index is None:
        index = VectorStoreIndex(
            batch,
            storage_context=storage_context,
            embed_model=embed_model
        )
    else:
        for attempt in range(max_retries):
            try:
                index.insert_nodes(batch)
                break  # success 
            except Exception as e:
                if "429" in str(e) or "rate limit" in str(e).lower():
                    wait_time = (2 ** attempt) + random.uniform(0, 1)
                    print(f"Rate limit hit. Retrying in {wait_time:.2f} seconds...")
                    time.sleep(wait_time)
                else:
                    raise

    if i + BATCH_SIZE < len(nodes):
        print(f"Waiting {DELAY} seconds before next batch...")
        time.sleep(DELAY)
# Out:
# Processing batch 1 of 44
# Waiting 1 seconds before next batch...
# Processing batch 2 of 44
# Waiting 1 seconds before next batch...
# Processing batch 3 of 44

# %% [markdown]
# ## BM25 Retrieval
#
#
# This part implements the BM25 Retrieval, wich filters the document collection using keyword matching. It identifies and ranks passages that share terms with the user’s query, selecting the top-scoring ones for further processing.

# %%
#bm25 retrieval function
def get_bm25_results(query: str, top_k: TOP_K):
    """Get top k results from BM25 search."""
    tokenized_query = query.lower().split()
    scores = bm25.get_scores(tokenized_query)

    results = []
    valid_indices = [(idx, score) for idx, score in enumerate(scores) if score > 0 and idx < len(nodes)]

    # Sort by score descending
    sorted_indices = sorted(valid_indices, key=lambda x: x[1], reverse=True)[:top_k]

    for idx, score in sorted_indices:
        results.append({
            "node": nodes[idx],
            "score": float(score),
            "text": nodes[idx].text
        })

    return results

# %% [markdown]
# ## Retrieval Strategies
#
# This step compares the BM25 and Vector Store Retrieval for finding relevant information. It runs both methods on the same user query and prints their top results side by side, allowing us to observe the differences in how each method identifies relevant content, together with the rank of each result.

# %%
tokenized_corpus = [node.text.lower().split() for node in nodes]
bm25 = BM25Okapi(tokenized_corpus)

def get_separate_retrievals(query: str):
    """Get separate results from BM25 and vector store retrievers."""
    print("=== BM25 Results ===")
    bm25_results = get_bm25_results(query, top_k=TOP_K)
    if bm25_results:
        for i, result in enumerate(bm25_results, 1):
            print(f"\n{i}. Score: {result['score']:.2f}")
            print(f"Text: {result['text'][:200]}...")
    
    print("\n=== Vector Store Results ===")
    # Create a query engine from the index
    query_engine = index.as_query_engine()
    response = query_engine.query(query)
    print(f"\nResponse: {response.response}")
    print("\nSource Nodes:")
    for i, node in enumerate(response.source_nodes, 1):
        print(f"\n{i}. Score: {node.score:.2f}")
        print(f"Text: {node.node.text[:200]}...")

# Example query for debugging and manual inspection
query = "what are the key issues discussed in the congressional hearings related to coronavirus?"
get_separate_retrievals(query)
# Out:
# === BM25 Results ===
#
# 1. Score: 19.62
# Text: Is that what we did? Dr. Walke. That is what--we had a multiprong approach to try to communicate the risk related to vaccines. But, again, I think we have a--there is a number of different communities...
#
# 2. Score: 18.16
# Text: And so, when we're talking about lessons learned, these are the kind of systemic things within agencies that I would like to hear: What are we doing to fix these things? What are we doing to make sure...
#
# 3. Score: 17.64
# Text: Cloud. That's my point, though. My point is that needs to change. So, you know, we brought this up in a number of Committee hearings how broke this process is. Are you doing anything to fix those thin...
#
# === Vector Store Results ===
#
# Response: Key issues discussed in the congressional hearings related to coronavirus include the need for stronger oversight, better accountability, and improved structure within agencies to ensure they act within their statutory responsibilities and subject-matter expertise. Additionally, there is a focus on the transparency, consistency, and credibility of public-health decisions. The hearings also touched upon the challenges faced during the COVID-19 pandemic, such as understanding the origins of the virus, the importance of accepting plausible theories, enhancing lab standards, preparing for naturally occurring pathogens, and improving communication of evolving information to the public.
#
# Source Nodes:
#
# 1. Score: 0.65
# Text: Stronger oversight, better accountability, and improved structure within our agencies are essential. Congress must consider a dedicated authority to oversee agency practices, ensuring that agencies ac...
#
# 2. Score: 0.65
# Text: We had the first hearing in Congress about this novel coronavirus and understood it was something different. We've now spent the better part of 4 years talking about COVID origins. I don't think we wi...

# %% [markdown]
# ## Comparing Top Answers from BM25 and Vector Store (Debugging)
#
# This function is used for **debugging and manual inspection** of the best answers retrieved by the two retrieval methods.
#
# For a given query, the script prints the **top result** from each method, allowing for side-by-side comparison. This helps assess which retrieval strategy provides more relevant or contextually appropriate information and guides further tuning of retrieval settings.

# %%
def get_best_answers(query: str):
    """Get the best answer from both BM25 and vector store retrievers."""
    
    # 1. Get BM25 results
    print("=== Best BM25 Answer ===")
    bm25_results = get_bm25_results(query, top_k=TOP_K)  # Get only the best result
    if bm25_results:
        best_bm25 = bm25_results[0]
        print(f"Score: {best_bm25['score']:.2f}")
        print(f"Text: {best_bm25['text']}")
    
    # 2. Get Vector Store results
    print("\n=== Best Vector Store Answer ===")
    query_engine = index.as_query_engine()
    response = query_engine.query(query)
    print(f"Response: {response.response}")
    if response.source_nodes:
        best_source = response.source_nodes[0]  # Get the best source
        print(f"\nBest Source Score: {best_source.score:.2f}")
        print(f"Source Text: {best_source.node.text}")

# Example usage
query = "what are the key issues discussed in the congressional hearing related to coronavirus?"
get_best_answers(query)
# Out:
# === Best BM25 Answer ===
# Score: 19.62
# Text: Is that what we did? Dr. Walke. That is what--we had a multiprong approach to try to communicate the risk related to vaccines. But, again, I think we have a--there is a number of different communities in our country, and we need to do better, I believe, at trying to reach those communities to talk to them about what are some of the issues they have with vaccine. Mr. Mfume. Dr. Tabak---- Dr. Wenstrup.
#
# === Best Vector Store Answer ===
# Response: Key issues discussed in the congressional hearing related to coronavirus include the need for stronger oversight, better accountability, and improved structure within agencies to ensure they act within their statutory responsibilities and subject-matter expertise. Additionally, there was a focus on the transparency, consistency, and credibility of public-health decisions, as well as the importance of accepting both natural and lab-origin theories regarding the virus to enhance lab standards and preparedness. The discussion also touched on the challenges of understanding and communicating evolving information during a pandemic.
#
# Best Source Score: 0.65
# Source Text: Stronger oversight, better accountability, and improved structure within our agencies are essential. Congress must consider a dedicated authority to oversee agency practices, ensuring that agencies act solely within their areas of statutory responsibilities and subject-matter expertise and insisting that public-health decisions are transparent, consistent, and credible. Let today's hearing be a step toward lasting reforms that will protect future generations from similar crises. I want to thank you, and I look forward to a strong on-topic discussion today. I would now like to recognize Ranking Member Ruiz for the purpose of making an opening statement. Dr. Ruiz. Thank you, Mr. Chairman. When COVID-19 hit our shores in the early months of 2020, our Nation began one of the most challenging chapters in its history.

# %% [markdown]
# ## LLM-Based Reranker
#
# This step uses OPENAI **GPT-4 Turbo** as a large language model to **rerank retrieved passages** based on their relevance to a given query. The goal is to refine the set of candidate chunks by prioritizing the most relevant ones.
#
# This step provides a **more context-aware ranking** that combines the passges retrieved from the BM25 and Vector retrieval. It is used to improve the quality of the answers generated by the RAG model.

# %%
# Instantiate the new LLM that will be used for the reranking
llm_gpt45 = OpenAI(model="gpt-4-turbo", temperature=0)

def rerank_with_llm(query, candidates, llm, top_k=3):
    prompt = (
        f"You are a helpful assistant tasked with reranking text passages for a user query.\n"
        f"Query: \"{query}\"\n\n"
        f"Here are {len(candidates)} candidate passages:\n"
    )
    for i, passage in enumerate(candidates, 1):
        prompt += f"{i}. {passage.strip()}\n\n"

    prompt += (
        "Based on their relevance to the query, return the top "
        f"{top_k} most relevant passage numbers in descending order of relevance.\n"
        "Example format: 3, 7, 1\n\n"
        "Top passages:"
    )

    response = llm.complete(prompt).text.strip()

    # Extract passage indices from the LLM's response
    match = re.findall(r'\d+', response)
    top_indices = [int(i) for i in match[:top_k] if int(i) <= len(candidates)]

    # Return the actual top-k passages
    return [candidates[i - 1] for i in top_indices]

# --- Example usage ---

query = "what are the key issues discussed in the congressional hearings related to coronavirus?"

# Retrieve passages
bm25_results = get_bm25_results(query, top_k=TOP_K)
vector_engine = index.as_query_engine()
vector_response = vector_engine.query(query)
vector_results = [node.node.text for node in vector_response.source_nodes[:3]]

# Merge and deduplicate
bm25_texts = [r['text'] for r in bm25_results]
candidates = list(dict.fromkeys(bm25_texts + vector_results))  # Keeps order, removes duplicates

# Rerank
reranked_passages = rerank_with_llm(query, candidates, llm_gpt45, top_k=3)

# Output
for i, passage in enumerate(reranked_passages, 1):
    print(f"Top {i}: {passage[:300]}...\n")
# Out:
# Top 1: Stronger oversight, better accountability, and improved structure within our agencies are essential. Congress must consider a dedicated authority to oversee agency practices, ensuring that agencies act solely within their areas of statutory responsibilities and subject-matter expertise and insisting...
#
# Top 2: And so, when we're talking about lessons learned, these are the kind of systemic things within agencies that I would like to hear: What are we doing to fix these things? What are we doing to make sure that we don't tread on people's civil rights again? What are we doing to make sure that we don't th...
#
# Top 3: Cloud. That's my point, though. My point is that needs to change. So, you know, we brought this up in a number of Committee hearings how broke this process is. Are you doing anything to fix those things? Are you doing anything to fix these other--before you come in and ask is for money, we still hav...

# %% [markdown]
# ## Main Question Answering Pipeline (Interactive Chatbot)
#
# This is the **primary QA interface** of the system, enabling users to ask questions about congressional hearings and receive grounded responses. It integrates all key components of the RAG pipeline, combining retrieval, reranking, and generation in a conversational loop.
#
# ### Key Functionalities:
# - **User Query Input:** Accepts free-form questions, including both open-ended and multiple-choice formats.
# - **Dual Retrieval:** Retrieves relevant passages using two methods:
#   - **BM25 (sparse)** — retrieves based on keyword overlap.
#   - **Vector Store (dense)** — retrieves based on semantic similarity.
# - **LLM-based Reranking:** Combines and reranks the retrieved passages using a powerful LLM to select the most relevant context for response generation.
# - **Answer Generation:** Generates responses using the selected passages, adapting the prompt based on question type.
# - **Multiple Response Views:** Returns answers generated from:
#   - BM25-only passages
#   - Vector-based passages
#   - Combined and reranked passages (primary answer)
# - **Contextual Dialogue Support:** Retains recent conversation history to support more coherent multi-turn interactions.
#
# > This serves as the **core QA experience** for users, integrating all system components into a coherent and interactive retrieval-augmented generation workflow.

# %%
def is_multiple_choice(question):
    """Looks for at least two options like 'A)', 'B)', etc."""
    options = re.findall(r'\b[A-Z]\)', question, re.IGNORECASE)
    return len(options) >= 2

conversation_history = []  # List of (user_question, llm_reply)

def synthesize_answer_with_llm(question, passages, llm, is_mc=False, history=None):
    messages = []
    # Add conversation history if provided
    if history:
        for user_q, llm_a in history:
            messages.append(ChatMessage(role=MessageRole.USER, content=user_q))
            messages.append(ChatMessage(role=MessageRole.ASSISTANT, content=llm_a))
    if is_mc:
        system_prompt = (
            "You are a concise assistant. Only answer using the information in the provided passages. "
            "If the answer is not contained in the passages, reply: 'The answer is not available in the provided texts.' "
            "If the user asks a multiple choice question, reply ONLY with the letter (A, B, C, etc.) of the best answer, unless otherwise specified. "
            "If you are unsure, reply with the most likely answer."
        )
        user_prompt = (
            f"Question: {question}\n\n"
            "Use the following passages to answer:\n" +
            "\n".join([f"[{i+1}] {p}" for i, p in enumerate(passages)]) +
            "\n\nPlease reply with the letter (A, B, C, etc.) of the best answer only."
        )
    else:
        system_prompt = (
            "You are a concise assistant. Only answer using the information in the provided passages. "
            "If the answer is not contained in the passages, reply: 'The answer is not available in the provided texts.' "
            "Provide short, factual answers to user questions. When a one-word or short phrase answer is sufficient, such as yes or no, or an answer, avoid elaboration. "
            "When more information is needed, provide a more detailed answer."
        )
        user_prompt = (
            f"Question: {question}\n\n"
            "Use the following passages to answer:\n" +
            "\n".join([f"[{i+1}] {p}" for i, p in enumerate(passages)]) +
            "\n\nPlease provide a concise and informative answer."
        )
    messages.insert(0, ChatMessage(role=MessageRole.SYSTEM, content=system_prompt))
    messages.append(ChatMessage(role=MessageRole.USER, content=user_prompt))
    response = llm.chat(messages)
    return response.message.content

# Chat loop
print("\n=== Congressional RAG Chatbot ===")
print("Type your questions about congressional documents.")
print("================================\n")

#exit phrases to terminate the chat
exit_phrases = {"exit", "done", "quit", "the conversation is finished", "conversation over", "end chat", ""}

while True:
    question = input("\nYour question: ").strip()
    if question.lower() in exit_phrases:
        print("Goodbye!")
        break

    bm25_results = get_bm25_results(question, top_k=TOP_K)
    bm25_texts = [r["text"] for r in bm25_results]
    vector_response = index.as_query_engine().query(question)
    vector_texts = [node.node.text for node in vector_response.source_nodes[:3]]

    candidates = list({*bm25_texts, *vector_texts})
    mc_flag = is_multiple_choice(question)
    history = conversation_history[-5:]

    # 1. Answer with only BM25 passages
    bm25_answer = synthesize_answer_with_llm(question, bm25_texts, llm, is_mc=mc_flag, history=history)
    # 2. Answer with only vector store passages
    vector_answer = synthesize_answer_with_llm(question, vector_texts, llm, is_mc=mc_flag, history=history)
    # 3. Answer with all combined passages
    reranked_passage = rerank_with_llm(question, candidates, llm)
    combined_answer = synthesize_answer_with_llm(question, [reranked_passage], llm, is_mc=mc_flag, history=history)

    print("\n LLM Answer from BM25 passages only:\n", bm25_answer)
    print("\n LLM Answer from Vedctor Store passages only:\n", vector_answer)
    print("\n LLM Answer from combined sources:\n", combined_answer)

    # Add to conversation history (using the combined answer)
    conversation_history.append((question, combined_answer))
# Out:
# === Congressional RAG Chatbot ===
# Type your questions about congressional documents.
# ================================
#
#
#  LLM Answer from BM25 passages only:
#  B
#
#  LLM Answer from Vedctor Store passages only:
#  B
#
#  LLM Answer from combined sources:
#  B
# Goodbye!

# %% [markdown]
# ## Model Evaluation
#
# This function is used to automatically generate questions from congressional transcript segments. By leveraging OpenAI’s GPT-3.5-Turbo, it prompts the model to produce **a single, clear, and specific question** grounded in the content of a given passage. This is primarily used for constructing an **evaluation dataset**, ensuring that all questions are contextually relevant and answerable based solely on the provided text. The approach enables scalable, consistent generation of questions for use in both automated and human evaluation settings.

# %%
def generate_question(text):
    try:
        llm = OpenAI(model="gpt-3.5-turbo", temperature=0.1)
        
        messages = [
            ChatMessage(
                role=MessageRole.SYSTEM,
                content="You are an expert question generator. Generate exactly one clear, specific, and answerable question based strictly on the passage provided."
            ),
            ChatMessage(
                role=MessageRole.USER,
                content=f"Passage:\n{text}\n\nPlease generate one question."
            )
        ]
        
        response = llm.chat(messages)
        return response.message.content.strip()
    except Exception as e:
        print(f"Error generating question: {e}")
        return "No question generated"

# %% [markdown]
# This segment constructs a dataset of question-context pairs for evaluation purposes. It iterates through the previously chunked nodes, filtering out segments that are too short to generate meaningful questions. For each valid chunk, it invokes the question generation function to create one question per passage. The process is rate-limited to comply with API usage policies and continues until the desired number of questions is reached. Finally, the dataset is saved in JSON format for later use in LLM-based or human evaluation pipelines.

# %%
# Initialize list to store question-context pairs
evaluation_dataset = []
questions_window_size = 10

# Generate up to 50 questions from chunked nodes
for idx, node in enumerate(nodes):
    context = node.text.strip()
    
    # Ensure context is of sufficient length
    if len(context.split()) < 20:
        continue  # skip overly short chunks
    
    print(f"Processing node {idx + 1}/500")
    
    question = generate_question(context)
    
    if question != "No question generated":
        evaluation_dataset.append({
            "context": context,
            "question": question
        })
    
    time.sleep(1)  # Basic rate limiting

# Save the improved dataset
output_file = f"congress_qc_dataset_window{questions_window_size}.json"
with open(output_file, "w") as f:
    json.dump(evaluation_dataset, f, indent=2)

print(f"✅ Saved {len(evaluation_dataset)} improved question-context pairs to {output_file}")
# Out:
# Processing node 1/500
# Processing node 2/500
# Processing node 3/500
# Processing node 4/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 23
#      17     if question != "No question generated":
#      18         evaluation_dataset.append({
#      19             "context": context,
#      20             "question": question
#      21         })
# ---> 23     time.sleep(1)  # Basic rate limiting
#      25 # Save the improved dataset
#      26 output_file = f"congress_qc_dataset_window{questions_window_size}.json"
#
# KeyboardInterrupt:

# %% [markdown]
# This section runs the full question-answering evaluation loop using a specified retrieval method — either BM25, dense vector retrieval, or a reranked version. For each question in the dataset, it retrieves relevant passages based on the chosen method and feeds them to the LLM to generate an answer. If reranking is enabled, the retrieved passages are refined using a second LLM pass. Retry logic is incorporated to handle potential rate limits, and final answers are saved along with their corresponding metadata for further evaluation.

# %%
# Choose retrieval method: "bm25", "vector", or "rerank2" for the answers to be generated
retrieval_method = "rerank2"  # Change this to switch methods based on the above

# Load your generated questions
with open(f"congress_qc_dataset_window{10}.json", "r") as f:
    qc_pairs = json.load(f)

# Initialize results container to keep track of the answers
answers = []

# Iterate over questions
for idx, pair in enumerate(qc_pairs):
    question = pair["question"]
    print(f"Answering question {idx + 1}/{len(qc_pairs)}")

    for attempt in range(3):  # Retry logic
        try:
            # Perform retrieval according to selected method
            if retrieval_method == "bm25":
                bm25_results = get_bm25_results(question, top_k=TOP_K)
                passages = [r["text"] for r in bm25_results if "text" in r]

            elif retrieval_method == "vector":
                vector_response = index.as_query_engine().query(question)
                passages = [node.node.text for node in vector_response.source_nodes[:TOP_K]] if vector_response.source_nodes else []

            #combined retrieval method is not used in the final report howeever it can be used in case more than one retrieval method is used and want to be combined
            elif retrieval_method == "combined" or retrieval_method == "rerank2":
                bm25_results = get_bm25_results(question, top_k=TOP_K)
                bm25_passages = [r["text"] for r in bm25_results if "text" in r]

                vector_response = index.as_query_engine().query(question)
                vector_passages = [node.node.text for node in vector_response.source_nodes[:TOP_K]] if vector_response.source_nodes else []

                passages = list(set(bm25_passages + vector_passages))

                # Apply reranking if requested
                if retrieval_method == "rerank2":
                    reranked_passage = rerank_with_llm(question, passages, llm)
                    print("ok")
                    passages = [reranked_passage]

            # Skip if no passages retrieved
            if not passages:
                print(f"No passages retrieved for question {idx + 1}, skipping.")
                answers.append({
                    "question": question,
                    "answer": "No relevant context retrieved.",
                    "window_size": CHUNK_SIZE,
                    "retrieval_method": retrieval_method
                })
                break

            # Synthesize answer
            answer = synthesize_answer_with_llm(question, passages, llm)

            # Save result
            answers.append({
                "question": question,
                "answer": answer,
                "window_size": CHUNK_SIZE,
                "retrieval_method": retrieval_method
            })
            #time.sleep(2)
            break  # Success

        except Exception as e:
            if "429" in str(e) or "rate limit" in str(e).lower():
                wait_time = (2 ** attempt) + random.uniform(0.5, 1.5)
                print(f" Rate limit. Retrying in {wait_time:.2f}s...")
                time.sleep(wait_time)
            else:
                print(f"↻ Attempt {attempt + 1} failed: {e}")
                if attempt == 2:
                    answers.append({
                        "question": question,
                        "answer": "Error",
                        "window_size": CHUNK_SIZE,
                        "retrieval_method": retrieval_method
                    })

# Save results
output_file = f"answers_{retrieval_method}_window{CHUNK_SIZE}.json"
with open(output_file, "w") as f:
    json.dump(answers, f, indent=2)

print(f"Answers saved to {output_file}")
# Out:
# Answering question 1/701
# ok
# Answering question 2/701
# ok
# Answering question 3/701
# ok
# Answering question 4/701
# ok
# Answering question 5/701
# ok
# Answering question 6/701
# ok
# Answering question 7/701
# ok
# Answering question 8/701
# ok
# Answering question 9/701
# ok
# Answering question 10/701
# ok
# Answering question 11/701
# ok
# Answering question 12/701
# ok
# Answering question 13/701
# ok
# Answering question 14/701
# ok
# Answering question 15/701
# ok
# Answering question 16/701
# ok
# Answering question 17/701
# ok
# Answering question 18/701
# ok
# Answering question 19/701
# ok
# Answering question 20/701
# ok
# Answering question 21/701
# ok
# Answering question 22/701
# ok
# Answering question 23/701
# ok
# Answering question 24/701
# ok
# Answering question 25/701
# ok
# Answering question 26/701
# ok
# Answering question 27/701
# ok
# Answering question 28/701
# ok
# Answering question 29/701
# ok
# Answering question 30/701
# ok
# Answering question 31/701
# ok
# Answering question 32/701
# ok
# Answering question 33/701
# ok
# Answering question 34/701
# ok
# Answering question 35/701
# ok
# Answering question 36/701
# ok
# Answering question 37/701
# ok
# Answering question 38/701
# ok
# Answering question 39/701
# ok
# Answering question 40/701
# ok
# Answering question 41/701
# ok
# Answering question 42/701
# ok
# Answering question 43/701
# ok
# Answering question 44/701
# ok
# Answering question 45/701
# ok
# Answering question 46/701
# ok
# Answering question 47/701
# ok
# Answering question 48/701
# ok
# Answering question 49/701
# ok
# Answering question 50/701
# ok
# Answering question 51/701
# ok
# Answering question 52/701
# ok
# Answering question 53/701
# ok
# Answering question 54/701
# ok
# Answering question 55/701
# ok
# Answering question 56/701
# ok
# Answering question 57/701
# ok
# Answering question 58/701
# ok
# Answering question 59/701
# ok
# Answering question 60/701
# ok
# Answering question 61/701
# ok
# Answering question 62/701
# ok
# Answering question 63/701
# ok
# Answering question 64/701
# ok
# Answering question 65/701
# ok
# Answering question 66/701
# ok
# Answering question 67/701
# ok
# Answering question 68/701
# ok
# Answering question 69/701
# ok
# Answering question 70/701
# ok
# Answering question 71/701
# ok
# Answering question 72/701
# ok
# Answering question 73/701
# ok
# Answering question 74/701
# ok
# Answering question 75/701
# ok
# Answering question 76/701
# ok
# Answering question 77/701
# ok
# Answering question 78/701
# ok
# Answering question 79/701
# ok
# Answering question 80/701
# ok
# Answering question 81/701
# ok
# Answering question 82/701
# ok
# Answering question 83/701
# ok
# Answering question 84/701
# ok
# Answering question 85/701
# ok
# Answering question 86/701
# ok
# Answering question 87/701
# ok
# Answering question 88/701
# ok
# Answering question 89/701
# ok
# Answering question 90/701
# ok
# Answering question 91/701
# ok
# Answering question 92/701
# ok
# Answering question 93/701
# ok
# Answering question 94/701
# ok
# Answering question 95/701
# ok
# Answering question 96/701
# ok
# Answering question 97/701
# ok
# Answering question 98/701
# ok
# Answering question 99/701
# ok
# Answering question 100/701
# ok
# Answering question 101/701
# ok
# Answering question 102/701
# ok
# Answering question 103/701
# ok
# Answering question 104/701
# ok
# Answering question 105/701
# ok
# Answering question 106/701
# ok
# Answering question 107/701
# ok
# Answering question 108/701
# ok
# Answering question 109/701
# ok
# Answering question 110/701
# ok
# Answering question 111/701
# ok
# Answering question 112/701
# ok
# Answering question 113/701
# ok
# Answering question 114/701
# ok
# Answering question 115/701
# ok
# Answering question 116/701
# ok
# Answering question 117/701
# ok
# Answering question 118/701
# ok
# Answering question 119/701
# ok
# Answering question 120/701
# ok
# Answering question 121/701
# ok
# Answering question 122/701
# ok
# Answering question 123/701
# ok
# Answering question 124/701
# ok
# Answering question 125/701
# ok
# Answering question 126/701
# ok
# Answering question 127/701
# ok
# Answering question 128/701
# ok
# Answering question 129/701
# ok
# Answering question 130/701
# ok
# Answering question 131/701
# ok
# Answering question 132/701
# ok
# Answering question 133/701
# ok
# Answering question 134/701
# ok
# Answering question 135/701
# ok
# Answering question 136/701
# ok
# Answering question 137/701
# ok
# Answering question 138/701
# ok
# Answering question 139/701
# ok
# Answering question 140/701
# ok
# Answering question 141/701
# ok
# Answering question 142/701
# ok
# Answering question 143/701
# ok
# Answering question 144/701
# ok
# Answering question 145/701
# ok
# Answering question 146/701
# ok
# Answering question 147/701
# ok
# Answering question 148/701
# ok
# Answering question 149/701
# ok
# Answering question 150/701
# ok
# Answering question 151/701
# ok
# Answering question 152/701
# ok
# Answering question 153/701
# ok
# Answering question 154/701
# ok
# Answering question 155/701
# ok
# Answering question 156/701
# ok
# Answering question 157/701
# ok
# Answering question 158/701
# ok
# Answering question 159/701
# ok
# Answering question 160/701
# ok
# Answering question 161/701
# ok
# Answering question 162/701
# ok
# Answering question 163/701
# ok
# Answering question 164/701
# ok
# Answering question 165/701
# ok
# Answering question 166/701
# ok
# Answering question 167/701
# ok
# Answering question 168/701
# ok
# Answering question 169/701
# ok
# Answering question 170/701
# ok
# Answering question 171/701
# ok
# Answering question 172/701
# ok
# Answering question 173/701
# ok
# Answering question 174/701
# ok
# Answering question 175/701
# ok
# Answering question 176/701
# ok
# Answering question 177/701
# ok
# Answering question 178/701
# ok
# Answering question 179/701
# ok
# Answering question 180/701
# ok
# Answering question 181/701
# ok
# Answering question 182/701
# ok
# Answering question 183/701
# ok
# Answering question 184/701
# ok
# Answering question 185/701
# ok
# Answering question 186/701
# ok
# Answering question 187/701
# ok
# Answering question 188/701
# ok
# Answering question 189/701
# ok
# Answering question 190/701
# ok
# Answering question 191/701
# ok
# Answering question 192/701
# ok
# Answering question 193/701
# ok
# Answering question 194/701
# ok
# Answering question 195/701
# ok
# Answering question 196/701
# ok
# Answering question 197/701
# ok
# Answering question 198/701
# ok
# Answering question 199/701
# ok
# Answering question 200/701
# ok
# Answering question 201/701
# ok
# Answering question 202/701
# ok
# Answering question 203/701
# ok
# Answering question 204/701
# ok
# Answering question 205/701
# ok
# Answering question 206/701
# ok
# Answering question 207/701
# ok
# Answering question 208/701
# ok
# Answering question 209/701
# ok
# Answering question 210/701
# ok
# Answering question 211/701
# ok
# Answering question 212/701
# ok
# Answering question 213/701
# ok
# Answering question 214/701
# ok
# Answering question 215/701
# ok
# Answering question 216/701
# ok
# Answering question 217/701
# ok
# Answering question 218/701
# ok
# Answering question 219/701
# ok
# Answering question 220/701
# ok
# Answering question 221/701
# ok
# Answering question 222/701
# ok
# ok
# Answering question 557/701
# ok
# Answering question 558/701
# ok
# Answering question 559/701
# ok
# Answering question 560/701
# ok
# Answering question 561/701
# ok
# Answering question 562/701
# ok
# Answering question 563/701
# ok
# Answering question 564/701
# ok
# Answering question 565/701
# ok
# Answering question 566/701
# ok
# Answering question 567/701
# ok
# Answering question 568/701
# ok
# Answering question 569/701
# ok
# Answering question 570/701
# ok
# Answering question 571/701
# ok
# Answering question 572/701
# ok
# Answering question 573/701
# ok
# Answering question 574/701
# ok
# Answering question 575/701
# ok
# Answering question 576/701
# ok
# Answering question 577/701
# ok
# Answering question 578/701
# ok
# Answering question 579/701
# ok
# Answering question 580/701
# ok
# Answering question 581/701
# ok
# Answering question 582/701
# ok
# Answering question 583/701
# ok
# Answering question 584/701
# ok
# Answering question 585/701
# ok
# Answering question 586/701
# ok
# Answering question 587/701
# ok
# Answering question 588/701
# ok
# Answering question 589/701
# ok
# Answering question 590/701
# ok
# Answering question 591/701
# ok
# Answering question 592/701
# ok
# Answering question 593/701
# ok
# Answering question 594/701
# ok
# Answering question 595/701
# ok
# Answering question 596/701
# ok
# Answering question 597/701
# ok
# Answering question 598/701
# ok
# Answering question 599/701
# ok
# Answering question 600/701
# ok
# Answering question 601/701
# ok
# Answering question 602/701
# ok
# Answering question 603/701
# ok
# Answering question 604/701
# ok
# Answering question 605/701
# ok
# Answering question 606/701
# ok
# Answering question 607/701
# ok
# Answering question 608/701
# ok
# Answering question 609/701
# ok
# Answering question 610/701
# ok
# Answering question 611/701
# ok
# Answering question 612/701
# ok
# Answering question 613/701
# ok
# Answering question 614/701
# ok
# Answering question 615/701
# ok
# Answering question 616/701
# ok
# Answering question 617/701
# ok
# Answering question 618/701
# ok
# Answering question 619/701
# ok
# Answering question 620/701
# ok
# Answering question 621/701
# ok
# Answering question 622/701
# ok
# Answering question 623/701
# ok
# Answering question 624/701
# ok
# Answering question 625/701
# ok
# Answering question 626/701
# ok
# Answering question 627/701
# ok
# Answering question 628/701
# ok
# Answering question 629/701
# ok
# Answering question 630/701
# ok
# Answering question 631/701
# ok
# Answering question 632/701
# ok
# Answering question 633/701
# ok
# Answering question 634/701
# ok
# Answering question 635/701
# ok
# Answering question 636/701
# ok
# Answering question 637/701
# ok
# Answering question 638/701
# ok
# Answering question 639/701
# ok
# Answering question 640/701
# ok
# Answering question 641/701
# ok
# Answering question 642/701
# ok
# Answering question 643/701
# ok
# Answering question 644/701
# ok
# Answering question 645/701
# ok
# Answering question 646/701
# ok
# Answering question 647/701
# ok
# Answering question 648/701
# ok
# Answering question 649/701
# ok
# Answering question 650/701
# ok
# Answering question 651/701
# ok
# Answering question 652/701
# ok
# Answering question 653/701
# ok
# Answering question 654/701
# ok
# Answering question 655/701
# ok
# Answering question 656/701
# ok
# Answering question 657/701
# ok
# Answering question 658/701
# ok
# Answering question 659/701
# ok
# Answering question 660/701
# ok
# Answering question 661/701
# ok
# Answering question 662/701
# ok
# Answering question 663/701
# ok
# Answering question 664/701
# ok
# Answering question 665/701
# ok
# Answering question 666/701
# ok
# Answering question 667/701
# ok
# Answering question 668/701
# ok
# Answering question 669/701
# ok
# Answering question 670/701
# ok
# Answering question 671/701
# ok
# Answering question 672/701
# ok
# Answering question 673/701
# ok
# Answering question 674/701
# ok
# Answering question 675/701
# ok
# Answering question 676/701
# ok
# Answering question 677/701
# ok
# Answering question 678/701
# ok
# Answering question 679/701
# ok
# Answering question 680/701
# ok
# Answering question 681/701
# ok
# Answering question 682/701
# ok
# Answering question 683/701
# ok
# Answering question 684/701
# ok
# Answering question 685/701
# ok
# Answering question 686/701
# ok
# Answering question 687/701
# ok
# Answering question 688/701
# ok
# Answering question 689/701
# ok
# Answering question 690/701
# ok
# Answering question 691/701
# ok
# Answering question 692/701
# ok
# Answering question 693/701
# ok
# Answering question 694/701
# ok
# Answering question 695/701
# ok
# Answering question 696/701
# ok
# Answering question 697/701
# ok
# Answering question 698/701
# ok
# Answering question 699/701
# ok
# Answering question 700/701
# ok
# Answering question 701/701
# ok
# ✅ Answers saved to answers_rerank2_window6.json

# %% [markdown]
# To assess the quality of answers generated by the system, an automatic evaluation pipeline is applied. For each question-answer pair, the system uses OpenAI’s GPT-3.5 to score the answer across three key aspects:
#
# - **Completeness**: Whether the response fully addresses the question with appropriate details.
# - **Relevance**: Whether the response stays focused on the original query without introducing unrelated information.
# - **Faithfulness**: Whether the response stays truthful to the given context and avoids hallucinations.
#
# Each aspect is rated on a strict 0–5 scale based on a predefined rubric, and a justification is provided for each score. The evaluation results are stored and summarized, including average scores across the dataset. This automated scoring provides a consistent and scalable way to measure model performance under different retrieval configurations which is used further in the report.

# %%
def evaluate_response(query: str, context: str, response: str) -> dict:
    """
    Evaluate a response based on Completeness, Relevance, and Faithfulness using a moderately strict rubric.
    """
    # Check if response indicates no answer available - automatically score as 0
    if response.strip().lower() == "the answer is not available in the provided texts.":
        return {
            "completeness": {"score": 0, "explanation": "No answer provided - system indicated answer not available"},
            "relevance": {"score": 0, "explanation": "No answer provided - system indicated answer not available"},
            "faithfulness": {"score": 0, "explanation": "No answer provided - system indicated answer not available"}
        }
    
    llm = OpenAI(model="gpt-3.5-turbo", temperature=0)

    evaluation_prompt = f"""You are a critical but fair evaluator. Evaluate the following response based on three metrics:

1. Completeness (0-5):
- 5: Fully answers the question with all key details and specific elements from the context. Minor omissions that don't alter the core are acceptable.
- 4: Good response that answers the question but lacks some secondary specifics or elaboration.
- 3: Partial answer that misses important content or is too generic.
- 2: Barely addresses the question or lacks coherence.
- 1: Mentions the topic but provides little to no substance.
- 0: Completely fails to address the question or answer is not available in the provided texts.

2. Relevance (0-5):
- 5: Response is tightly focused on the question with no off-topic content.
- 4: Mostly relevant, with only minor digressions or extra details.
- 3: Includes relevant content but is diluted by tangents or unrelated points.
- 2: Weak focus on the question; mostly off-topic.
- 1: Barely relevant.
- 0: Irrelevant or answer is not available in the provided texts.

3. Faithfulness (0-5):
- 5: Fully grounded in the provided context. All claims are supported.
- 4: Minor inferences or stylistic interpretations, but no factual hallucinations.
- 3: Some information not found in context or assumptions present.
- 2: Deviates clearly from the facts in the context.
- 1: Mostly incorrect based on the context.
- 0: Entirely misrepresents the context or answer is not available in the provided texts.

Question: {query}

Context: {context}

Response: {response}

Instructions:
- Assign a score from 0-5 for each metric.
- Justify each score with a clear explanation.
- Be fair but avoid giving perfect scores unless justified.

Return the result as JSON with this format:
{{
    "completeness": {{
        "score": int,
        "explanation": "string"
    }},
    "relevance": {{
        "score": int,
        "explanation": "string"
    }},
    "faithfulness": {{
        "score": int,
        "explanation": "string"
    }}
}}"""

    messages = [
        ChatMessage(
            role=MessageRole.SYSTEM,
            content="You are a fair and methodical evaluator of NLP model outputs. Follow the rubric exactly."
        ),
        ChatMessage(
            role=MessageRole.USER,
            content=evaluation_prompt
        )
    ]

    try:
        evaluation = llm.chat(messages)
        return json.loads(evaluation.message.content)
    except Exception as e:
        print(f"Error during evaluation: {e}")
        return {
            "completeness": {"score": 0, "explanation": "Evaluation failed"},
            "relevance": {"score": 0, "explanation": "Evaluation failed"},
            "faithfulness": {"score": 0, "explanation": "Evaluation failed"}
        }

def save_evaluations_to_json(answers_rerank_window, retrieval_method, output_file=None):
    """
    Evaluate and save results for all answers in the rerank window to a JSON file.
    Uses context from congress_qc_dataset_window10.json for each question.
    """
    if output_file is None:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        output_file = f"evaluation_results_{retrieval_method}_{timestamp}.json"
    
    # Load the original dataset to get the context for each question
    print(f"Loading original dataset to get question-specific context for {retrieval_method}...")
    try:
        with open('congress_qc_dataset_window10.json', 'r', encoding='utf-8') as f:
            original_dataset = json.load(f)
        
        # Create a mapping of questions to their original context
        question_to_context = {}
        for item in original_dataset:
            question_to_context[item['question']] = item['context']
        
        print(f"Loaded {len(question_to_context)} question-context pairs from original dataset")
    except FileNotFoundError:
        print("Warning: congress_qc_dataset_window10.json not found. Using fallback context.")
        question_to_context = {}
    except Exception as e:
        print(f"Error loading original dataset: {e}. Using fallback context.")
        question_to_context = {}
    
    # Evaluate all answers
    answers_to_evaluate = answers_rerank_window
    results = []
    
    print(f"Processing all {len(answers_to_evaluate)} answers for {retrieval_method}...")
    
    for idx, answer in enumerate(answers_to_evaluate):
        # Extract fields using the correct keys from your JSON
        query = answer.get('question', '')
        response = answer.get('answer', '')
        
        if not all([query, response]):
            print(f"Warning: Missing required fields in answer {idx}. Skipping...")
            continue
        
        # Get the original context for this question
        original_context = question_to_context.get(query, "Context not found in original dataset")
        
        print(f"Evaluating answer {idx + 1}/{len(answers_to_evaluate)} for {retrieval_method}")
        evaluation = evaluate_response(
            query=query,
            context=original_context,  # Use the original context from the dataset
            response=response
        )
        
        # Create a more concise result entry
        result_entry = {
            "question": query,
            "answer": response,
            "retrieval_method": retrieval_method,
            "original_context": original_context[:200] + "..." if len(original_context) > 200 else original_context,
            "scores": {
                "completeness": evaluation["completeness"]["score"],
                "relevance": evaluation["relevance"]["score"],
                "faithfulness": evaluation["faithfulness"]["score"]
            },
            "explanations": {
                "completeness": evaluation["completeness"]["explanation"],
                "relevance": evaluation["relevance"]["explanation"],
                "faithfulness": evaluation["faithfulness"]["explanation"]
            }
        }
        results.append(result_entry)
    
    if not results:
        print(f"No valid answers were found to evaluate for {retrieval_method}!")
        return None
    
    # Calculate average scores
    avg_scores = {
        "completeness": sum(r["scores"]["completeness"] for r in results) / len(results),
        "relevance": sum(r["scores"]["relevance"] for r in results) / len(results),
        "faithfulness": sum(r["scores"]["faithfulness"] for r in results) / len(results)
    }
    
    # Create final output structure
    output = {
        "timestamp": datetime.now().isoformat(),
        "retrieval_method": retrieval_method,
        "total_answers": len(results),
        "average_scores": avg_scores,
        "answers": results  # List of answers with their scores
    }
    
    # Save to JSON file
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(output, f, indent=2, ensure_ascii=False)
    
    print(f"\nEvaluation results saved to: {output_file}")
    print(f"\nAverage Scores for {retrieval_method}:")
    for metric, score in avg_scores.items():
        print(f"{metric.capitalize()}: {score:.2f}")
    
    return output_file

# Define all retrieval methods to evaluate
retrieval_methods = ["bm25", "vector", "rerank2"]

# Load the original dataset once
print("Loading original dataset to get question-specific context...")
try:
    with open('congress_qc_dataset_window10.json', 'r', encoding='utf-8') as f:
        original_dataset = json.load(f)
    
    # Create a mapping of questions to their original context
    question_to_context = {}
    for item in original_dataset:
        question_to_context[item['question']] = item['context']
    
    print(f"Loaded {len(question_to_context)} question-context pairs from original dataset")
except FileNotFoundError:
    print("Warning: congress_qc_dataset_window10.json not found. Using fallback context.")
    question_to_context = {}
except Exception as e:
    print(f"Error loading original dataset: {e}. Using fallback context.")
    question_to_context = {}

# Run evaluation for all retrieval methods
all_results = {}

for retrieval_method in retrieval_methods:
    print(f"\n{'='*60}")
    print(f"EVALUATING {retrieval_method.upper()} RETRIEVAL METHOD")
    print(f"{'='*60}")
    
    try:
        filename = f'answers_{retrieval_method}_window{CHUNK_SIZE}.json'
        with open(filename, 'r', encoding='utf-8') as f:
            answers_rerank_window = json.load(f)
        
        output_filename = f"evaluation_scores_{retrieval_method}_window{CHUNK_SIZE}_all_questions.json"

        output_file = save_evaluations_to_json(
            answers_rerank_window,
            retrieval_method,
            output_filename
        )
        
        if output_file:
            all_results[retrieval_method] = output_file
            
    except FileNotFoundError:
        print(f"Error: answers file for {retrieval_method} not found!")
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in answers file for {retrieval_method}!")
    except Exception as e:
        print(f"An unexpected error occurred for {retrieval_method}: {e}")

# Print summary of all results
print(f"\n{'='*60}")
print("EVALUATION SUMMARY")
print(f"{'='*60}")
print(f"Successfully evaluated {len(all_results)} out of {len(retrieval_methods)} retrieval methods:")
for method, file_path in all_results.items():
    print(f" {method}: {file_path}")

if len(all_results) == len(retrieval_methods):
    print("\n All retrieval methods have been successfully evaluated!")
else:
    print(f"\n  {len(retrieval_methods) - len(all_results)} retrieval method(s) failed to evaluate.")
# Out:
# Loading original dataset to get question-specific context...
# Loaded 699 question-context pairs from original dataset
#
# ============================================================
# EVALUATING BM25 RETRIEVAL METHOD
# ============================================================
# Loading original dataset to get question-specific context for bm25...
# Loaded 699 question-context pairs from original dataset
# Processing all 701 answers for bm25...
# Evaluating answer 1/701 for bm25
# Evaluating answer 2/701 for bm25
# Evaluating answer 3/701 for bm25
# Evaluating answer 4/701 for bm25
# Evaluating answer 5/701 for bm25
# Evaluating answer 6/701 for bm25
# Evaluating answer 7/701 for bm25
# Evaluating answer 699/701 for bm25
# Evaluating answer 700/701 for bm25
# Evaluating answer 701/701 for bm25
#
# Evaluation results saved to: evaluation_scores_bm25_window6_all_questions.json
#
# Average Scores for bm25:
# Completeness: 3.24
# Relevance: 3.80
# Faithfulness: 3.33
#
# ============================================================
# EVALUATING VECTOR RETRIEVAL METHOD
# ============================================================
# Loading original dataset to get question-specific context for vector...
# Loaded 699 question-context pairs from original dataset
# Processing all 701 answers for vector...
# Evaluating answer 1/701 for vector
# Evaluating answer 2/701 for vector
# Evaluating answer 3/701 for vector
# Evaluating answer 4/701 for vector
# Evaluating answer 5/701 for vector
# Evaluating answer 6/701 for vector
# Evaluating answer 7/701 for vector
# Evaluating answer 8/701 for vector
# Evaluating answer 9/701 for vector
# Evaluating answer 10/701 for vector
# Evaluating answer 11/701 for vector
# Evaluating answer 12/701 for vector
# Evaluating answer 13/701 for vector
# Evaluating answer 14/701 for vector
# Evaluating answer 15/701 for vector
# Evaluating answer 16/701 for vector
# Evaluating answer 17/701 for vector
# Evaluating answer 18/701 for vector
# Evaluating answer 19/701 for vector
# Evaluating answer 20/701 for vector
# Evaluating answer 21/701 for vector
# Evaluating answer 22/701 for vector
# Evaluating answer 23/701 for vector
# Evaluating answer 24/701 for vector
# Evaluating answer 25/701 for vector
# Evaluating answer 26/701 for vector
# Evaluating answer 27/701 for vector
# Evaluating answer 28/701 for vector
# Evaluating answer 29/701 for vector
# Evaluating answer 30/701 for vector
# Evaluating answer 31/701 for vector
# Evaluating answer 32/701 for vector
# Evaluating answer 33/701 for vector
# Evaluating answer 34/701 for vector
# Evaluating answer 35/701 for vector
# Evaluating answer 36/701 for vector
# Evaluating answer 37/701 for vector
# Evaluating answer 38/701 for vector
# Evaluating answer 39/701 for vector
# Evaluating answer 40/701 for vector
# Evaluating answer 41/701 for vector
# Evaluating answer 42/701 for vector
# Evaluating answer 43/701 for vector
# Evaluating answer 44/701 for vector
# Evaluating answer 45/701 for vector
# Evaluating answer 46/701 for vector
# Evaluating answer 47/701 for vector
# Evaluating answer 48/701 for vector
# Evaluating answer 49/701 for vector
# Evaluating answer 50/701 for vector
# Evaluating answer 51/701 for vector
# Evaluating answer 52/701 for vector
# Evaluating answer 53/701 for vector
# Evaluating answer 54/701 for vector
# Evaluating answer 55/701 for vector
# Evaluating answer 56/701 for vector
# Evaluating answer 57/701 for vector
# Evaluating answer 58/701 for vector
# Evaluating answer 59/701 for vector
# Evaluating answer 60/701 for vector
# Evaluating answer 61/701 for vector
# Evaluating answer 62/701 for vector
# Evaluating answer 63/701 for vector
# Evaluating answer 64/701 for vector
# Evaluating answer 65/701 for vector
# Evaluating answer 66/701 for vector
# Evaluating answer 67/701 for vector
# Evaluating answer 68/701 for vector
# Evaluating answer 69/701 for vector
# Evaluating answer 70/701 for vector
# Evaluating answer 71/701 for vector
# Evaluating answer 72/701 for vector
# Evaluating answer 73/701 for vector
# Evaluating answer 74/701 for vector
# Evaluating answer 75/701 for vector
# Evaluating answer 76/701 for vector
# Evaluating answer 77/701 for vector
# Evaluating answer 78/701 for vector
# Evaluating answer 79/701 for vector
# Evaluating answer 80/701 for vector
# Evaluating answer 81/701 for vector
# Evaluating answer 82/701 for vector
# Evaluating answer 83/701 for vector
# Evaluating answer 84/701 for vector
# Evaluating answer 85/701 for vector
# Evaluating answer 86/701 for vector
# Evaluating answer 87/701 for vector
# Evaluating answer 88/701 for vector
# Evaluating answer 89/701 for vector
# Evaluating answer 90/701 for vector
# Evaluating answer 91/701 for vector
# Evaluating answer 92/701 for vector
# Evaluating answer 93/701 for vector
# Evaluating answer 94/701 for vector
# Evaluating answer 95/701 for vector
# Evaluating answer 96/701 for vector
# Evaluating answer 97/701 for vector
# Evaluating answer 98/701 for vector
# Evaluating answer 99/701 for vector
# Evaluating answer 100/701 for vector
# Evaluating answer 101/701 for vector
# Evaluating answer 102/701 for vector
# Evaluating answer 103/701 for vector
# Evaluating answer 104/701 for vector
# Evaluating answer 105/701 for vector
# Evaluating answer 106/701 for vector
# Evaluating answer 107/701 for vector
# Evaluating answer 108/701 for vector
# Evaluating answer 109/701 for vector
# Evaluating answer 110/701 for vector
# Evaluating answer 111/701 for vector
# Evaluating answer 112/701 for vector
# Evaluating answer 113/701 for vector
# Evaluating answer 114/701 for vector
# Evaluating answer 115/701 for vector
# Evaluating answer 116/701 for vector
# Evaluating answer 117/701 for vector
# Evaluating answer 118/701 for vector
# Evaluating answer 119/701 for vector
# Evaluating answer 120/701 for vector
# Evaluating answer 121/701 for vector
# Evaluating answer 122/701 for vector
# Evaluating answer 123/701 for vector
# Evaluating answer 124/701 for vector
# Evaluating answer 125/701 for vector
# Evaluating answer 126/701 for vector
# Evaluating answer 127/701 for vector
# Evaluating answer 128/701 for vector
# Evaluating answer 129/701 for vector
# Evaluating answer 130/701 for vector
# Evaluating answer 131/701 for vector
# Evaluating answer 132/701 for vector
# Evaluating answer 133/701 for vector
# Evaluating answer 134/701 for vector
# Evaluating answer 135/701 for vector
# Evaluating answer 136/701 for vector
# Evaluating answer 137/701 for vector
# Evaluating answer 138/701 for vector
# Evaluating answer 139/701 for vector
# Evaluating answer 140/701 for vector
# Evaluating answer 141/701 for vector
# Evaluating answer 142/701 for vector
# Evaluating answer 143/701 for vector
# Evaluating answer 144/701 for vector
# Evaluating answer 145/701 for vector
# Evaluating answer 146/701 for vector
# Evaluating answer 147/701 for vector
# Evaluating answer 148/701 for vector
# Evaluating answer 149/701 for vector
# Evaluating answer 150/701 for vector
# Evaluating answer 151/701 for vector
# Evaluating answer 152/701 for vector
# Evaluating answer 153/701 for vector
# Evaluating answer 154/701 for vector
# Evaluating answer 155/701 for vector
# Evaluating answer 156/701 for vector
# Evaluating answer 157/701 for vector
# Evaluating answer 158/701 for vector
# Evaluating answer 159/701 for vector
# Evaluating answer 160/701 for vector
# Evaluating answer 161/701 for vector
# Evaluating answer 162/701 for vector
# Evaluating answer 163/701 for vector
# Evaluating answer 164/701 for vector
# Evaluating answer 165/701 for vector
# Evaluating answer 166/701 for vector
# Evaluating answer 167/701 for vector
# Evaluating answer 168/701 for vector
# Evaluating answer 169/701 for vector
# Evaluating answer 170/701 for vector
# Evaluating answer 171/701 for vector
# Evaluating answer 172/701 for vector
# Evaluating answer 173/701 for vector
# Evaluating answer 174/701 for vector
# Evaluating answer 175/701 for vector
# Evaluating answer 176/701 for vector
# Evaluating answer 177/701 for vector
# Evaluating answer 178/701 for vector
# Evaluating answer 179/701 for vector
# Evaluating answer 180/701 for vector
# Evaluating answer 181/701 for vector
# Evaluating answer 182/701 for vector
# Evaluating answer 183/701 for vector
# Evaluating answer 184/701 for vector
# Evaluating answer 185/701 for vector
# Evaluating answer 186/701 for vector
# Evaluating answer 187/701 for vector
# Evaluating answer 188/701 for vector
# Evaluating answer 189/701 for vector
# Evaluating answer 190/701 for vector
# Evaluating answer 191/701 for vector
# Evaluating answer 192/701 for vector
# Evaluating answer 193/701 for vector
# Evaluating answer 194/701 for vector
# Evaluating answer 195/701 for vector
# Evaluating answer 196/701 for vector
# Evaluating answer 197/701 for vector
# Evaluating answer 198/701 for vector
# Evaluating answer 199/701 for vector
# Evaluating answer 200/701 for vector
# Evaluating answer 201/701 for vector
# Evaluating answer 202/701 for vector
# Evaluating answer 203/701 for vector
# Evaluating answer 204/701 for vector
# Evaluating answer 205/701 for vector
# Evaluating answer 206/701 for vector
# Evaluating answer 207/701 for vector
# Evaluating answer 208/701 for vector
# Evaluating answer 209/701 for vector
# Evaluating answer 210/701 for vector
# Evaluating answer 211/701 for vector
# Evaluating answer 212/701 for vector
# Evaluating answer 213/701 for vector
# Evaluating answer 214/701 for vector
# Evaluating answer 215/701 for vector
# Evaluating answer 216/701 for vector
# Evaluating answer 217/701 for vector
# Evaluating answer 218/701 for vector
# Evaluating answer 219/701 for vector
# Evaluating answer 220/701 for vector
# Evaluating answer 221/701 for vector
# Evaluating answer 222/701 for vector
# Evaluating answer 223/701 for vector
# Evaluating answer 224/701 for vector
# Evaluating answer 225/701 for vector
# Evaluating answer 226/701 for vector
# Evaluating answer 227/701 for vector
# Evaluating answer 228/701 for vector
# Evaluating answer 229/701 for vector
# Evaluating answer 230/701 for vector
# Evaluating answer 231/701 for vector
# Evaluating answer 232/701 for vector
# Evaluating answer 233/701 for vector
# Evaluating answer 234/701 for vector
# Evaluating answer 235/701 for vector
# Evaluating answer 236/701 for vector
# Evaluating answer 237/701 for vector
# Evaluating answer 238/701 for vector
# Evaluating answer 239/701 for vector
# Evaluating answer 240/701 for vector
# Evaluating answer 241/701 for vector
# Evaluating answer 242/701 for vector
# Evaluating answer 243/701 for vector
# Evaluating answer 244/701 for vector
# Evaluating answer 245/701 for vector
# Evaluating answer 246/701 for vector
# Evaluating answer 247/701 for vector
# Evaluating answer 248/701 for vector
# Evaluating answer 249/701 for vector
# Evaluating answer 250/701 for vector
# Evaluating answer 251/701 for vector
# Evaluating answer 252/701 for vector
# Evaluating answer 253/701 for vector
# Evaluating answer 254/701 for vector
# Evaluating answer 255/701 for vector
# Evaluating answer 256/701 for vector
# Evaluating answer 257/701 for vector
# Evaluating answer 258/701 for vector
# Evaluating answer 259/701 for vector
# Evaluating answer 260/701 for vector
# Evaluating answer 261/701 for vector
# Evaluating answer 262/701 for vector
# Evaluating answer 263/701 for vector
# Evaluating answer 264/701 for vector
# Evaluating answer 265/701 for vector
# Evaluating answer 266/701 for vector
# Evaluating answer 267/701 for vector
# Evaluating answer 268/701 for vector
# Evaluating answer 269/701 for vector
# Evaluating answer 270/701 for vector
# Evaluating answer 271/701 for vector
# Evaluating answer 272/701 for vector
# Evaluating answer 273/701 for vector
# Evaluating answer 274/701 for vector
# Evaluating answer 275/701 for vector
# Evaluating answer 276/701 for vector
# Evaluating answer 277/701 for vector
# Evaluating answer 278/701 for vector
# Evaluating answer 279/701 for vector
# Evaluating answer 280/701 for vector
# Evaluating answer 281/701 for vector
# Evaluating answer 282/701 for vector
# Evaluating answer 283/701 for vector
# Evaluating answer 284/701 for vector
# Evaluating answer 285/701 for vector
# Evaluating answer 286/701 for vector
# Evaluating answer 287/701 for vector
# Evaluating answer 288/701 for vector
# Evaluating answer 289/701 for vector
# Evaluating answer 290/701 for vector
# Evaluating answer 291/701 for vector
# Evaluating answer 292/701 for vector
# Evaluating answer 293/701 for vector
# Evaluating answer 294/701 for vector
# Evaluating answer 295/701 for vector
# Evaluating answer 296/701 for vector
# Evaluating answer 297/701 for vector
# Evaluating answer 298/701 for vector
# Evaluating answer 299/701 for vector
# Evaluating answer 300/701 for vector
# Evaluating answer 301/701 for vector
# Evaluating answer 302/701 for vector
# Evaluating answer 303/701 for vector
# Evaluating answer 304/701 for vector
# Evaluating answer 305/701 for vector
# Evaluating answer 306/701 for vector
# Evaluating answer 307/701 for vector
# Evaluating answer 308/701 for vector
# Evaluating answer 309/701 for vector
# Evaluating answer 310/701 for vector
# Evaluating answer 311/701 for vector
# Evaluating answer 312/701 for vector
# Evaluating answer 313/701 for vector
# Evaluating answer 314/701 for vector
# Evaluating answer 315/701 for vector
# Evaluating answer 316/701 for vector
# Evaluating answer 317/701 for vector
# Evaluating answer 318/701 for vector
# Evaluating answer 319/701 for vector
# Evaluating answer 320/701 for vector
# Evaluating answer 321/701 for vector
# Evaluating answer 322/701 for vector
# Evaluating answer 323/701 for vector
# Evaluating answer 324/701 for vector
# Evaluating answer 325/701 for vector
# Evaluating answer 326/701 for vector
# Evaluating answer 327/701 for vector
# Evaluating answer 328/701 for vector
# Evaluating answer 329/701 for vector
# Evaluating answer 330/701 for vector
# Evaluating answer 331/701 for vector
# Evaluating answer 332/701 for vector
# Evaluating answer 333/701 for vector
# Evaluating answer 334/701 for vector
# Evaluating answer 335/701 for vector
# Evaluating answer 336/701 for vector
# Evaluating answer 337/701 for vector
# Evaluating answer 338/701 for vector
# Evaluating answer 339/701 for vector
# Evaluating answer 340/701 for vector
# Evaluating answer 341/701 for vector
# Evaluating answer 342/701 for vector
# Evaluating answer 343/701 for vector
# Evaluating answer 344/701 for vector
# Evaluating answer 345/701 for vector
# Evaluating answer 346/701 for vector
# Evaluating answer 347/701 for vector
# Evaluating answer 348/701 for vector
# Evaluating answer 349/701 for vector
# Evaluating answer 350/701 for vector
# Evaluating answer 351/701 for vector
# Evaluating answer 352/701 for vector
# Evaluating answer 353/701 for vector
# Evaluating answer 354/701 for vector
# Evaluating answer 355/701 for vector
# Evaluating answer 356/701 for vector
# Evaluating answer 357/701 for vector
# Evaluating answer 358/701 for vector
# Evaluating answer 359/701 for vector
# Evaluating answer 360/701 for vector
# Evaluating answer 361/701 for vector
# Evaluating answer 362/701 for vector
# Evaluating answer 363/701 for vector
# Evaluating answer 364/701 for vector
# Evaluating answer 365/701 for vector
# Evaluating answer 366/701 for vector
# Evaluating answer 367/701 for vector
# Evaluating answer 368/701 for vector
# Evaluating answer 369/701 for vector
# Evaluating answer 370/701 for vector
# Evaluating answer 371/701 for vector
# Evaluating answer 372/701 for vector
# Evaluating answer 373/701 for vector
# Evaluating answer 374/701 for vector
# Evaluating answer 375/701 for vector
# Evaluating answer 376/701 for vector
# Evaluating answer 377/701 for vector
# Evaluating answer 378/701 for vector
# Evaluating answer 379/701 for vector
# Evaluating answer 380/701 for vector
# Evaluating answer 381/701 for vector
# Evaluating answer 382/701 for vector
# Evaluating answer 383/701 for vector
# Evaluating answer 384/701 for vector
# Evaluating answer 385/701 for vector
# Evaluating answer 386/701 for vector
# Evaluating answer 387/701 for vector
# Evaluating answer 388/701 for vector
# Evaluating answer 389/701 for vector
# Evaluating answer 390/701 for vector
# Evaluating answer 391/701 for vector
# Evaluating answer 392/701 for vector
# Evaluating answer 393/701 for vector
# Evaluating answer 394/701 for vector
# Evaluating answer 395/701 for vector
# Evaluating answer 396/701 for vector
# Evaluating answer 397/701 for vector
# Evaluating answer 398/701 for vector
# Evaluating answer 399/701 for vector
# Evaluating answer 400/701 for vector
# Evaluating answer 401/701 for vector
# Evaluating answer 402/701 for vector
# Evaluating answer 403/701 for vector
# Evaluating answer 404/701 for vector
# Evaluating answer 405/701 for vector
# Evaluating answer 406/701 for vector
# Evaluating answer 407/701 for vector
# Evaluating answer 408/701 for vector
# Evaluating answer 409/701 for vector
# Evaluating answer 410/701 for vector
# Evaluating answer 411/701 for vector
# Evaluating answer 412/701 for vector
# Evaluating answer 413/701 for vector
# Evaluating answer 414/701 for vector
# Evaluating answer 415/701 for vector
# Evaluating answer 416/701 for vector
# Evaluating answer 417/701 for vector
# Evaluating answer 418/701 for vector
# Evaluating answer 419/701 for vector
# Evaluating answer 420/701 for vector
# Evaluating answer 421/701 for vector
# Evaluating answer 422/701 for vector
# Evaluating answer 423/701 for vector
# Evaluating answer 424/701 for vector
# Evaluating answer 425/701 for vector
# Evaluating answer 426/701 for vector
# Evaluating answer 427/701 for vector
# Evaluating answer 428/701 for vector
# Evaluating answer 429/701 for vector
# Evaluating answer 430/701 for vector
# Evaluating answer 431/701 for vector
# Evaluating answer 432/701 for vector
# Evaluating answer 433/701 for vector
# Evaluating answer 434/701 for vector
# Evaluating answer 435/701 for vector
# Evaluating answer 436/701 for vector
# Evaluating answer 437/701 for vector
# Evaluating answer 438/701 for vector
# Evaluating answer 439/701 for vector
# Evaluating answer 440/701 for vector
# Evaluating answer 441/701 for vector
# Evaluating answer 442/701 for vector
# Evaluating answer 443/701 for vector
# Evaluating answer 444/701 for vector
# Evaluating answer 445/701 for vector
# Evaluating answer 446/701 for vector
# Evaluating answer 447/701 for vector
# Evaluating answer 448/701 for vector
# Evaluating answer 449/701 for vector
# Evaluating answer 450/701 for vector
# Evaluating answer 451/701 for vector
# Evaluating answer 452/701 for vector
# Evaluating answer 453/701 for vector
# Evaluating answer 454/701 for vector
# Evaluating answer 455/701 for vector
# Evaluating answer 456/701 for vector
# Evaluating answer 457/701 for vector
# Evaluating answer 458/701 for vector
# Evaluating answer 459/701 for vector
# Evaluating answer 460/701 for vector
# Evaluating answer 461/701 for vector
# Evaluating answer 462/701 for vector
# Evaluating answer 463/701 for vector
# Evaluating answer 464/701 for vector
# Evaluating answer 465/701 for vector
# Evaluating answer 466/701 for vector
# Evaluating answer 467/701 for vector
# Evaluating answer 468/701 for vector
# Evaluating answer 469/701 for vector
# Evaluating answer 470/701 for vector
# Evaluating answer 471/701 for vector
# Evaluating answer 472/701 for vector
# Evaluating answer 473/701 for vector
# Evaluating answer 474/701 for vector
# Evaluating answer 475/701 for vector
# Evaluating answer 476/701 for vector
# Evaluating answer 477/701 for vector
# Evaluating answer 478/701 for vector
# Evaluating answer 479/701 for vector
# Evaluating answer 480/701 for vector
# Evaluating answer 481/701 for vector
# Evaluating answer 482/701 for vector
# Evaluating answer 483/701 for vector
# Evaluating answer 484/701 for vector
# Evaluating answer 485/701 for vector
# Evaluating answer 486/701 for vector
# Evaluating answer 487/701 for vector
# Evaluating answer 488/701 for vector
# Evaluating answer 489/701 for vector
# Evaluating answer 490/701 for vector
# Evaluating answer 491/701 for vector
# Evaluating answer 492/701 for vector
# Evaluating answer 493/701 for vector
# Evaluating answer 494/701 for vector
# Evaluating answer 495/701 for vector
# Evaluating answer 496/701 for vector
# Evaluating answer 497/701 for vector
# Evaluating answer 498/701 for vector
# Evaluating answer 499/701 for vector
# Evaluating answer 500/701 for vector
# Evaluating answer 501/701 for vector
# Evaluating answer 502/701 for vector
# Evaluating answer 503/701 for vector
# Evaluating answer 504/701 for vector
# Evaluating answer 505/701 for vector
# Evaluating answer 506/701 for vector
# Evaluating answer 507/701 for vector
# Evaluating answer 508/701 for vector
# Evaluating answer 509/701 for vector
# Evaluating answer 510/701 for vector
# Evaluating answer 511/701 for vector
# Evaluating answer 512/701 for vector
# Evaluating answer 513/701 for vector
# Evaluating answer 514/701 for vector
# Evaluating answer 515/701 for vector
# Evaluating answer 516/701 for vector
# Evaluating answer 517/701 for vector
# Evaluating answer 518/701 for vector
# Evaluating answer 519/701 for vector
# Evaluating answer 520/701 for vector
# Evaluating answer 521/701 for vector
# Evaluating answer 522/701 for vector
# Evaluating answer 523/701 for vector
# Evaluating answer 524/701 for vector
# Evaluating answer 525/701 for vector
# Evaluating answer 526/701 for vector
# Evaluating answer 527/701 for vector
# Evaluating answer 528/701 for vector
# Evaluating answer 529/701 for vector
# Evaluating answer 530/701 for vector
# Evaluating answer 531/701 for vector
# Evaluating answer 532/701 for vector
# Evaluating answer 533/701 for vector
# Evaluating answer 534/701 for vector
# Evaluating answer 535/701 for vector
# Evaluating answer 536/701 for vector
# Evaluating answer 537/701 for vector
# Evaluating answer 538/701 for vector
# Evaluating answer 539/701 for vector
# Evaluating answer 540/701 for vector
# Evaluating answer 541/701 for vector
# Evaluating answer 542/701 for vector
# Evaluating answer 543/701 for vector
# Evaluating answer 544/701 for vector
# Evaluating answer 545/701 for vector
# Evaluating answer 546/701 for vector
# Evaluating answer 547/701 for vector
# Evaluating answer 548/701 for vector
# Evaluating answer 549/701 for vector
# Evaluating answer 550/701 for vector
# Evaluating answer 551/701 for vector
# Evaluating answer 552/701 for vector
# Evaluating answer 553/701 for vector
# Evaluating answer 554/701 for vector
# Evaluating answer 555/701 for vector
# Evaluating answer 556/701 for vector
# Evaluating answer 557/701 for vector
# Evaluating answer 558/701 for vector
# Evaluating answer 559/701 for vector
# Evaluating answer 560/701 for vector
# Evaluating answer 561/701 for vector
# Evaluating answer 562/701 for vector
# Evaluating answer 563/701 for vector
# Evaluating answer 564/701 for vector
# Evaluating answer 565/701 for vector
# Evaluating answer 566/701 for vector
# Evaluating answer 567/701 for vector
# Evaluating answer 568/701 for vector
# Evaluating answer 569/701 for vector
# Evaluating answer 570/701 for vector
# Evaluating answer 571/701 for vector
# Evaluating answer 572/701 for vector
# Evaluating answer 573/701 for vector
# Evaluating answer 574/701 for vector
# Evaluating answer 575/701 for vector
# Evaluating answer 576/701 for vector
# Evaluating answer 577/701 for vector
# Evaluating answer 578/701 for vector
# Evaluating answer 579/701 for vector
# Evaluating answer 580/701 for vector
# Evaluating answer 581/701 for vector
# Evaluating answer 582/701 for vector
# Evaluating answer 583/701 for vector
# Evaluating answer 584/701 for vector
# Evaluating answer 585/701 for vector
# Evaluating answer 586/701 for vector
# Evaluating answer 587/701 for vector
# Evaluating answer 588/701 for vector
# Evaluating answer 589/701 for vector
# Evaluating answer 590/701 for vector
# Evaluating answer 591/701 for vector
# Evaluating answer 592/701 for vector
# Evaluating answer 593/701 for vector
# Evaluating answer 594/701 for vector
# Evaluating answer 595/701 for vector
# Evaluating answer 596/701 for vector
# Evaluating answer 597/701 for vector
# Evaluating answer 598/701 for vector
# Evaluating answer 599/701 for vector
# Evaluating answer 600/701 for vector
# Evaluating answer 601/701 for vector
# Evaluating answer 602/701 for vector
# Evaluating answer 603/701 for vector
# Evaluating answer 604/701 for vector
# Evaluating answer 605/701 for vector
# Evaluating answer 606/701 for vector
# Evaluating answer 607/701 for vector
# Evaluating answer 608/701 for vector
# Evaluating answer 609/701 for vector
# Evaluating answer 610/701 for vector
# Evaluating answer 611/701 for vector
# Evaluating answer 612/701 for vector
# Evaluating answer 613/701 for vector
# Evaluating answer 614/701 for vector
# Evaluating answer 615/701 for vector
# ...
# Evaluating answer 297/701 for rerank2
# Evaluating answer 298/701 for rerank2
# Evaluating answer 299/701 for rerank2
# Evaluating answer 300/701 for rerank2
# Evaluating answer 301/701 for rerank2
# Evaluating answer 302/701 for rerank2
# Evaluating answer 303/701 for rerank2
# Evaluating answer 304/701 for rerank2
# Evaluating answer 305/701 for rerank2
# Evaluating answer 306/701 for rerank2
# Evaluating answer 634/701 for rerank2
# Evaluating answer 635/701 for rerank2
# Evaluating answer 636/701 for rerank2
# Evaluating answer 637/701 for rerank2
# Evaluating answer 638/701 for rerank2
# Evaluating answer 639/701 for rerank2
# Evaluating answer 640/701 for rerank2
# Evaluating answer 641/701 for rerank2
# Evaluating answer 642/701 for rerank2
# Evaluating answer 643/701 for rerank2
# Evaluating answer 644/701 for rerank2
# Evaluating answer 645/701 for rerank2
# Evaluating answer 646/701 for rerank2
# Evaluating answer 647/701 for rerank2
# Evaluating answer 648/701 for rerank2
# Evaluating answer 649/701 for rerank2
# Evaluating answer 650/701 for rerank2
# Evaluating answer 651/701 for rerank2
# Evaluating answer 652/701 for rerank2
# Evaluating answer 653/701 for rerank2
# Evaluating answer 654/701 for rerank2
# Evaluating answer 655/701 for rerank2
# Evaluating answer 656/701 for rerank2
# Evaluating answer 657/701 for rerank2
# Evaluating answer 658/701 for rerank2
# Evaluating answer 659/701 for rerank2
# Evaluating answer 660/701 for rerank2
# Evaluating answer 661/701 for rerank2
# Evaluating answer 662/701 for rerank2
# Evaluating answer 663/701 for rerank2
# Evaluating answer 664/701 for rerank2
# Evaluating answer 665/701 for rerank2
# Evaluating answer 666/701 for rerank2
# Evaluating answer 667/701 for rerank2
# Evaluating answer 668/701 for rerank2
# Evaluating answer 669/701 for rerank2
# Evaluating answer 670/701 for rerank2
# Evaluating answer 671/701 for rerank2
# Evaluating answer 672/701 for rerank2
# Evaluating answer 673/701 for rerank2
# Evaluating answer 674/701 for rerank2
# Evaluating answer 675/701 for rerank2
# Evaluating answer 676/701 for rerank2
# Evaluating answer 677/701 for rerank2
# Evaluating answer 678/701 for rerank2
# Evaluating answer 679/701 for rerank2
# Evaluating answer 680/701 for rerank2
# Evaluating answer 681/701 for rerank2
# Evaluating answer 682/701 for rerank2
# Evaluating answer 683/701 for rerank2
# Evaluating answer 684/701 for rerank2
# Evaluating answer 685/701 for rerank2
# Evaluating answer 686/701 for rerank2
# Evaluating answer 687/701 for rerank2
# Evaluating answer 688/701 for rerank2
# Evaluating answer 689/701 for rerank2
# Evaluating answer 690/701 for rerank2
# Evaluating answer 691/701 for rerank2
# Evaluating answer 692/701 for rerank2
# Evaluating answer 693/701 for rerank2
# Evaluating answer 694/701 for rerank2
# Evaluating answer 695/701 for rerank2
# Evaluating answer 696/701 for rerank2
# Evaluating answer 697/701 for rerank2
# Evaluating answer 698/701 for rerank2
# Evaluating answer 699/701 for rerank2
# Evaluating answer 700/701 for rerank2
# Evaluating answer 701/701 for rerank2
#
# Evaluation results saved to: evaluation_scores_rerank2_window6_all_questions.json
#
# Average Scores for rerank2:
# Completeness: 3.67
# Relevance: 4.33
# Faithfulness: 3.76
#
# ============================================================
# EVALUATION SUMMARY
# ============================================================
# Successfully evaluated 3 out of 3 retrieval methods:
# ✓ bm25: evaluation_scores_bm25_window6_all_questions.json
# ✓ vector: evaluation_scores_vector_window6_all_questions.json
# ✓ rerank2: evaluation_scores_rerank2_window6_all_questions.json
#
# 🎉 All retrieval methods have been successfully evaluated!
